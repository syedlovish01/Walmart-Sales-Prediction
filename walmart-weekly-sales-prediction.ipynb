# %% [markdown]
# ### Data Loading

# %%
import pandas as pd

df = pd.read_csv('Walmart_Sales.csv')

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# ...

# %% [markdown]
# ### Wrong Data Type

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %% [markdown]
# ### Null Values

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# ### Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Target Value

# %%
df['Weekly_Sales'].describe()
# Out:
# count    6.435000e+03
# mean     1.046965e+06
# std      5.643666e+05
# min      2.099862e+05
# 25%      5.533501e+05
# 50%      9.607460e+05
# 75%      1.420159e+06
# max      3.818686e+06
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# ### Unique Values

# %%
df['Store'].nunique()
# Out:
# 45

# %% [markdown]
# ### Data Time Range

# %%
df['Date'].min(), df['Date'].max()
# Out:
# (Timestamp('2010-02-05 00:00:00'), Timestamp('2012-10-26 00:00:00'))

# %% [markdown]
# ### Sort by Time

# %%
df = df.sort_values('Date')

# %%
df.head()
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1287     10 2010-02-05    2193048.75             0        54.34       2.962
# 5148     37 2010-02-05     536006.73             0        45.97       2.572
# 2288     17 2010-02-05     789036.02             0        23.11       2.666
# 4147     30 2010-02-05     465108.52             0        39.05       2.572
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1287  126.442065         9.765
# 5148  209.852966         8.554
# 2288  126.442065         6.548
# 4147  210.752605         8.324

# %% [markdown]
# ### Now Data Analysis

# %%
df.groupby('Date')['Weekly_Sales'].sum().plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Checking store dependencies

# %%
df[df['Store'] == 1].groupby('Date')['Weekly_Sales'].sum().plot(figsize=(10,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df[df['Store'] == 2].groupby('Date')['Weekly_Sales'].sum().plot(figsize=(10,4))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Store 1 & 2 Sales comparission

# %%
df[df['Store'] == 1].groupby('Date')['Weekly_Sales'].sum().plot(figsize=(10,4), label='Store 1')
df[df['Store'] == 2].groupby('Date')['Weekly_Sales'].sum().plot(figsize=(10,4), label='Store 2')

import matplotlib.pyplot as plt
plt.legend()

# %%
df.groupby('Store')['Weekly_Sales'].mean()
# Out:
# Store
# 1     1.555264e+06
# 2     1.925751e+06
# 3     4.027044e+05
# 4     2.094713e+06
# 5     3.180118e+05
# 6     1.564728e+06
# 7     5.706173e+05
# 8     9.087495e+05
# 9     5.439806e+05
# 10    1.899425e+06
# 11    1.356383e+06
# 12    1.009002e+06
# 13    2.003620e+06
# 14    2.020978e+06
# 15    6.233125e+05
# 16    5.192477e+05
# 17    8.935814e+05
# 18    1.084718e+06
# 19    1.444999e+06
# 20    2.107677e+06
# 21    7.560691e+05
# 22    1.028501e+06
# 23    1.389864e+06
# 24    1.356755e+06
# 25    7.067215e+05
# 26    1.002912e+06
# 27    1.775216e+06
# 28    1.323522e+06
# 29    5.394514e+05
# 30    4.385796e+05
# 31    1.395901e+06
# 32    1.166568e+06
# 33    2.598617e+05
# 34    9.667816e+05
# 35    9.197250e+05
# 36    3.735120e+05
# 37    5.189003e+05
# 38    3.857317e+05
# 39    1.450668e+06
# 40    9.641280e+05
# 41    1.268125e+06
# 42    5.564039e+05
# 43    6.333247e+05
# 44    3.027489e+05
# 45    7.859814e+05
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# ### Which store perform better

# %%
df.groupby('Store')['Weekly_Sales'].mean().sort_values(ascending=False)
# Out:
# Store
# 20    2.107677e+06
# 4     2.094713e+06
# 14    2.020978e+06
# 13    2.003620e+06
# 2     1.925751e+06
# 10    1.899425e+06
# 27    1.775216e+06
# 6     1.564728e+06
# 1     1.555264e+06
# 39    1.450668e+06
# 19    1.444999e+06
# 31    1.395901e+06
# 23    1.389864e+06
# 24    1.356755e+06
# 11    1.356383e+06
# 28    1.323522e+06
# 41    1.268125e+06
# 32    1.166568e+06
# 18    1.084718e+06
# 22    1.028501e+06
# 12    1.009002e+06
# 26    1.002912e+06
# 34    9.667816e+05
# 40    9.641280e+05
# 35    9.197250e+05
# 8     9.087495e+05
# 17    8.935814e+05
# 45    7.859814e+05
# 21    7.560691e+05
# 25    7.067215e+05
# 43    6.333247e+05
# 15    6.233125e+05
# 7     5.706173e+05
# 42    5.564039e+05
# 9     5.439806e+05
# 29    5.394514e+05
# 16    5.192477e+05
# 37    5.189003e+05
# 30    4.385796e+05
# 3     4.027044e+05
# 38    3.857317e+05
# 36    3.735120e+05
# 5     3.180118e+05
# 44    3.027489e+05
# 33    2.598617e+05
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# ### So store number 20 generates higher revenue and 33 is the lowest.

# %% [markdown]
# Comparing the revenue generated by top and lowest store during Holidays

# %%
df[df['Store'] == 20].groupby('Date')['Weekly_Sales'].sum().plot(figsize=(10,4), label='Store 20')

df[df['Store'] == 33].groupby('Date')['Weekly_Sales'].sum().plot(figsize=(10,4), label='Store 33')

import matplotlib.pyplot as plt
plt.legend()

# %% [markdown]
# ## Outcome:
# ### While holidays drive significant sales spikes in high-performing stores, low-performing stores show limited response, indicating that holiday impact is store-dependent rather than uniform.

# %%
df.groupby('Holiday_Flag')['Weekly_Sales'].mean()
# Out:
# Holiday_Flag
# 0    1.041256e+06
# 1    1.122888e+06
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# ### Holidays increase average sales moderately, but the effect varies across stores, with some showing strong spikes and others minimal impact.

# %%
df.head()
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1287     10 2010-02-05    2193048.75             0        54.34       2.962
# 5148     37 2010-02-05     536006.73             0        45.97       2.572
# 2288     17 2010-02-05     789036.02             0        23.11       2.666
# 4147     30 2010-02-05     465108.52             0        39.05       2.572
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1287  126.442065         9.765
# 5148  209.852966         8.554
# 2288  126.442065         6.548
# 4147  210.752605         8.324

# %% [markdown]
# ### Now Sales vs Temperature

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='Temperature', y='Weekly_Sales', data=df)
plt.show()

# %% [markdown]
# ### The scatter plot shows no clear linear relationship between temperature and sales, suggesting that temperature is not a strong predictor of weekly sales.

# %%
df.corr(numeric_only=True)
# Out:
#                      Store  Weekly_Sales  Holiday_Flag  Temperature  \
# Store         1.000000e+00     -0.335332  1.637929e-16    -0.022659
# Weekly_Sales -3.353320e-01      1.000000  3.689097e-02    -0.063810
# Holiday_Flag  1.637929e-16      0.036891  1.000000e+00    -0.155091
# Temperature  -2.265908e-02     -0.063810 -1.550913e-01     1.000000
# Fuel_Price    6.002295e-02      0.009464 -7.834652e-02     0.144982
# CPI          -2.094919e-01     -0.072634 -2.162091e-03     0.176888
# Unemployment  2.235313e-01     -0.106176  1.096028e-02     0.101158
#
#               Fuel_Price       CPI  Unemployment
# Store           0.060023 -0.209492      0.223531
# Weekly_Sales    0.009464 -0.072634     -0.106176
# Holiday_Flag   -0.078347 -0.002162      0.010960
# Temperature     0.144982  0.176888      0.101158
# Fuel_Price      1.000000 -0.170642     -0.034684
# CPI            -0.170642  1.000000     -0.302020
# Unemployment   -0.034684 -0.302020      1.000000

# %% [markdown]
# ### Although correlation suggested weak relationships for some features like holidays, exploratory analysis revealed that holidays have a strong non-linear impact on sales.

# %% [markdown]
# ##                                           Time for Feature Engineering!!

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Week'] = df['Date'].dt.isocalendar().week

# %%
df[['Date','Year','Month','Week']].head()
# Out:
#            Date  Year  Month  Week
# 0    2010-02-05  2010      2     5
# 1287 2010-02-05  2010      2     5
# 5148 2010-02-05  2010      2     5
# 2288 2010-02-05  2010      2     5
# 4147 2010-02-05  2010      2     5

# %% [markdown]
# ### Temporal features such as year, month, and week were extracted to capture seasonal patterns and improve model learning.

# %% [markdown]
# ### Lag Features
# ### Past sales help predict future sales

# %%
df = df.sort_values(['Store', 'Date'])

df['Lag_1'] = df.groupby('Store')['Weekly_Sales'].shift(1)
df['Lag_2'] = df.groupby('Store')['Weekly_Sales'].shift(2)

# %%
df[['Store','Date','Weekly_Sales','Lag_1','Lag_2']].head(10)
# Out:
#    Store       Date  Weekly_Sales       Lag_1       Lag_2
# 0      1 2010-02-05    1643690.90         NaN         NaN
# 1      1 2010-02-12    1641957.44  1643690.90         NaN
# 2      1 2010-02-19    1611968.17  1641957.44  1643690.90
# 3      1 2010-02-26    1409727.59  1611968.17  1641957.44
# 4      1 2010-03-05    1554806.68  1409727.59  1611968.17
# 5      1 2010-03-12    1439541.59  1554806.68  1409727.59
# 6      1 2010-03-19    1472515.79  1439541.59  1554806.68
# 7      1 2010-03-26    1404429.92  1472515.79  1439541.59
# 8      1 2010-04-02    1594968.28  1404429.92  1472515.79
# 9      1 2010-04-09    1545418.53  1594968.28  1404429.92

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# Year            0
# Month           0
# Week            0
# Lag_1           0
# Lag_2           0
# dtype: int64

# %% [markdown]
# ### Train-Test Split

# %%
split_date = '2012-01-01'

train = df[df['Date'] < split_date].copy()
test = df[df['Date'] >= split_date].copy()

# %%
X_train = train.drop(['Weekly_Sales', 'Date'], axis=1)
y_train = train['Weekly_Sales']

X_test = test.drop(['Weekly_Sales', 'Date'], axis=1)
y_test = test['Weekly_Sales']

# %%
X_train = pd.get_dummies(X_train, columns=['Store'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['Store'], drop_first=True)

# Make sure both train and test have same columns
X_train, X_test = X_train.align(X_test, join='left', axis=1, fill_value=0)

# %% [markdown]
# ## 1. Model: Linear Regression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("R2:", r2)
# Out:
# MAE: 76701.94601745583
# R2: 0.9625636735477268

# %% [markdown]
# ## 2. Model: Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred_rf = rf.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("Random Forest MAE:", mae_rf)
print("Random Forest R2:", r2_rf)
# Out:
# Random Forest MAE: 60225.46915390184
# Random Forest R2: 0.9747279831857906

# %% [markdown]
# ## 3. Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)

y_pred_ridge = ridge.predict(X_test)

print("Ridge MAE:", mean_absolute_error(y_test, y_pred_ridge))
print("Ridge R2:", r2_score(y_test, y_pred_ridge))
# Out:
# Ridge MAE: 72581.4690272871
# Ridge R2: 0.9642259895857108

# %% [markdown]
# I used Ridge to check if Linear regression & Ridge behaves differently or not, I suspected data leakage but nothing like that.

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

print("KNN MAE:", mean_absolute_error(y_test, y_pred_knn))
print("KNN R2:", r2_score(y_test, y_pred_knn))
# Out:
# KNN MAE: 73201.11591007753
# KNN R2: 0.9594339205051117

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor(random_state=42)
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print("DT MAE:", mean_absolute_error(y_test, y_pred_dt))
print("DT R2:", r2_score(y_test, y_pred_dt))
# Out:
# DT MAE: 88216.1830749354
# DT R2: 0.9467659978207106

# %%
X_train_no_lag = X_train.drop(['Lag_1', 'Lag_2'], axis=1)
X_test_no_lag = X_test.drop(['Lag_1', 'Lag_2'], axis=1)

# %%
lr = LinearRegression()
lr.fit(X_train_no_lag, y_train)

y_pred_lr = lr.predict(X_test_no_lag)

print("LR (no lag) MAE:", mean_absolute_error(y_test, y_pred_lr))
print("LR (no lag) R2:", r2_score(y_test, y_pred_lr))
# Out:
# LR (no lag) MAE: 96882.44517140424
# LR (no lag) R2: 0.9444380716488653

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train_no_lag, y_train)

y_pred_rf = rf.predict(X_test_no_lag)

print("RF (no lag) MAE:", mean_absolute_error(y_test, y_pred_rf))
print("RF (no lag) R2:", r2_score(y_test, y_pred_rf))
# Out:
# RF (no lag) MAE: 94116.897654677
# RF (no lag) R2: 0.9027631056972267
